# %%
# !python --version
# Out:
# Python 3.12.13

# %%
x=10
y=3.14
z=2 + 5j
flag=True

print(type(x))
print(type(y))
print(type(z))
print(type(flag))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>
