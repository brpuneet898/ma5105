# %%
# !python --version
# Out:
# Python 3.12.13

# %%
x=10
y=3.14
z=2 + 5j
flag=True

print(type(x))
print(type(y))
print(type(z))
print(type(flag))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>

# %%
print(float(3))
print(int(3.9))
# Out:
# 3.0
# 3

# %%
print(3+2)
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
roi=10.0
prin=1000.0
time=6
interest = prin * roi * time / 100
print(interest)
# Out:
# 600.0

# %%
print(round(2.3))
print(round(3.14159,3))
print(round(2.65,1.4))
# Out:
# 2
# 3.142
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4443/1660369128.py in <cell line: 0>()
#       1 print(round(2.3))
#       2 print(round(3.14159,3))
# ----> 3 print(round(2.65,1.4))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
print(abs(3))
print(abs(-5.0))

print(pow(2,3))
print(pow(2,-2))
print(pow(2,3,2))
# Out:
# 3
# 5.0
# 8
# 0.25
# 0

# %%
pow
# Out:
# <function pow(base, exp, mod=None)>

# %%
hi="hello there"
name="puneet"
greeting=hi + " " + name
print(greeting)
# Out:
# hello there puneet

# %%
flavor="apple pie"
print(flavor[0:3])
# Out:
# app

# %%
word="goal"
word[0]="f"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4443/671274159.py in <cell line: 0>()
#       1 word="goal"
# ----> 2 word[0]="f"
#
# TypeError: 'str' object does not support item assignment

# %%
int(word)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4443/3176636073.py in <cell line: 0>()
# ----> 1 int(word)
#
# ValueError: invalid literal for int() with base 10: 'goal'

# %%
x="10"
print(int(x))
# Out:
# 10

# %%
x=str(10)
print(x)
# Out:
# 10

# %%
text=input("Enter your name: ")
print(text)
# Out:
# Puneet

# %%
word="I am in a class."
print(len(word))
# Out:
# 16
