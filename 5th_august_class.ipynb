# %%
for letter in "Python":
    print(letter)
# Out:
# P
# y
# t
# h
# o
# n

# %%
w = "python"
i=0
while i < len(w):
    print(w[i])
    i += 1
# Out:
# p
# y
# t
# h
# o
# n

# %%
def f(x):
    return x**2

N=100
dx=1/N

integral = 0

for i in range(N):
    x = i*dx
    integral = integral + f(x)*dx

print(integral)
# Out:
# 0.32835000000000014

# %%
def f(x, y):
    return (x+y)

N=100
dx=1/N
dy=1/N

integral1 = 0
integral2 = 0

for i in range(N):
    for j in range(N):
        x = i*dx
        y = j*dy
        integral1 = integral1 + f(x, y)*dx*dy

print(integral1)
# Out:
# 0.9900000000000035

# %%
x = "hello"

def f(x):
    x=2
    print(x)

f(x=x)
print(x)
# Out:
# 2
# hello

# %%
total = 0
def addtototal(x):
    global total
    total = total + x

addtototal(5)
print(total)
# Out:
# 5

# %%
n = 17
if n % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
a=int(input("Enter a number: "))
b=int(input("Enter another number: "))
c=int(input("Enter another number: "))

d = (b**2) - (4*a*c)

if d > 0:
    print("Roots are real and different")
elif d == 0:
    print("Roots are real and same")
else:
    print("Roots are complex")
